# %%
# %matplotlib widget
import os
import json
import csv 
import matplotlib as mpl

# %%
path = '/Users/antoniocangelosi/Documents/GitHub/cognitive-battery/cognitive-battery/data/ANT.json'

def load_multiple_json(filepath):
	data = []
	with open(filepath, 'r') as file:
		for line in file:
			data.append(json.loads(line))
	return data

data = load_multiple_json(path)
